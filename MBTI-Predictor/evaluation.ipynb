# %%
import os
from pyspark.ml import PipelineModel
from pyspark.sql import SparkSession

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"


if "_JAVA_OPTIONS" in os.environ:
    del os.environ["_JAVA_OPTIONS"]

try:
    spark = SparkSession.builder \
        .appName("MBTI_SparkNLP_Loader") \
        .config("spark.jars.packages", "com.johnsnowlabs.nlp:spark-nlp_2.12:3.1.0") \
        .config("spark.driver.maxResultSize", "0") \
        .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
        .config("spark.driver.memory", "4g") \
        .config("spark.kryoserializer.buffer.max", "256m") \
        .getOrCreate()
    print("Spark Session 啟動成功！")

except Exception as e:
    print(f"Spark Session 啟動失敗，請檢查系統 PATH 和 JDK 安裝: {e}")
# Out:
# 25/12/11 17:17:30 WARN Utils: Your hostname, jolin-System-Product-Name resolves to a loopback address: 127.0.1.1; using 140.118.127.138 instead (on interface eno1)
# 25/12/11 17:17:30 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/jolin/miniconda3/envs/CAA-MBTI-Predictor/lib/python3.9/site-packages/pyspark/jars/spark-unsafe_2.12-3.1.2.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Ivy Default Cache set to: /home/jolin/.ivy2/cache
# The jars for the packages stored in: /home/jolin/.ivy2/jars
# com.johnsnowlabs.nlp#spark-nlp_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-559c0de7-6c7a-44b9-879a-46d96f21b17d;1.0
# 	confs: [default]
# :: loading settings :: url = jar:file:/home/jolin/miniconda3/envs/CAA-MBTI-Predictor/lib/python3.9/site-packages/pyspark/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 	found com.johnsnowlabs.nlp#spark-nlp_2.12;3.1.0 in central
# 	found com.typesafe#config;1.3.0 in central
# 	found org.rocksdb#rocksdbjni;6.5.3 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.11.603 in central
# 	found com.github.universal-automata#liblevenshtein;3.0.0 in central
# 	found com.google.code.findbugs#annotations;3.0.1 in central
# 	found net.jcip#jcip-annotations;1.0 in central
# 	found com.google.code.findbugs#jsr305;3.0.1 in central
# 	found com.google.protobuf#protobuf-java-util;3.0.0-beta-3 in central
# 	found com.google.protobuf#protobuf-java;3.0.0-beta-3 in central
# 	found com.google.code.gson#gson;2.3 in central
# 	found it.unimi.dsi#fastutil;7.0.12 in central
# 	found org.projectlombok#lombok;1.16.8 in central
# 	found org.slf4j#slf4j-api;1.7.21 in central
# 	found com.navigamez#greex;1.0 in central
# 	found dk.brics.automaton#automaton;1.11-8 in central
# 	found org.json4s#json4s-ext_2.12;3.5.3 in central
# 	found joda-time#joda-time;2.9.5 in central
# 	found org.joda#joda-convert;1.8.1 in central
# 	found com.johnsnowlabs.nlp#tensorflow-cpu_2.12;0.3.1 in central
# 	found net.sf.trove4j#trove4j;3.0.3 in central
# :: resolution report :: resolve 296ms :: artifacts dl 7ms
# 	:: modules in use:
# 	com.amazonaws#aws-java-sdk-bundle;1.11.603 from central in [default]
# 	com.github.universal-automata#liblevenshtein;3.0.0 from central in [default]
# 	com.google.code.findbugs#annotations;3.0.1 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.1 from central in [default]
# 	com.google.code.gson#gson;2.3 from central in [default]
# 	com.google.protobuf#protobuf-java;3.0.0-beta-3 from central in [default]
# 	com.google.protobuf#protobuf-java-util;3.0.0-beta-3 from central in [default]
# 	com.johnsnowlabs.nlp#spark-nlp_2.12;3.1.0 from central in [default]
# 	com.johnsnowlabs.nlp#tensorflow-cpu_2.12;0.3.1 from central in [default]
# 	com.navigamez#greex;1.0 from central in [default]
# 	com.typesafe#config;1.3.0 from central in [default]
# 	dk.brics.automaton#automaton;1.11-8 from central in [default]
# 	it.unimi.dsi#fastutil;7.0.12 from central in [default]
# 	joda-time#joda-time;2.9.5 from central in [default]
# 	net.jcip#jcip-annotations;1.0 from central in [default]
# 	net.sf.trove4j#trove4j;3.0.3 from central in [default]
# 	org.joda#joda-convert;1.8.1 from central in [default]
# 	org.json4s#json4s-ext_2.12;3.5.3 from central in [default]
# 	org.projectlombok#lombok;1.16.8 from central in [default]
# 	org.rocksdb#rocksdbjni;6.5.3 from central in [default]
# 	org.slf4j#slf4j-api;1.7.21 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   21  |   0   |   0   |   0   ||   21  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-559c0de7-6c7a-44b9-879a-46d96f21b17d
# 	confs: [default]
# 	0 artifacts copied, 21 already retrieved (0kB/7ms)
# 25/12/11 17:17:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Spark Session 啟動成功！

# %%
import re
from pyspark.sql.functions import udf
import pandas as pd

def preprocess_english_posts(text):
    """
    將英文文本進行預處理：
    1. 將句子結束符號（. ! ?）替換為 ||| 
    2. 移除其他常見標點符號，並清理多餘的空白。
    """
    if not isinstance(text, str) or not text:
        return ""
    
    # 替換英文的句子結束符為 ||| 
    # [\.!?] 匹配句號、驚嘆號、問號
    # \s* 匹配標點符號前後的任意空白字符
    text = re.sub(r'\s*([\.!?])\s*', ' ||| ', text)
    
    # 移除其他常見標點符號（例如：逗號, 括號, 引號, 冒號, 分號）
    # 這裡保留了 ||| 供後續處理
    text = re.sub(r'[,()\'"\-\:\;]', '', text)
    
    # 清理多餘的空白
    text = re.sub(r'\s+', ' ', text).strip()

    # 處理可能產生的重複分隔符
    text = re.sub(r'\s*\|\|\|\s*', '|||', text) 
    text = re.sub(r'\|\|\|+', '|||', text)
    
    # 確保開頭和結尾沒有 |||
    if text.endswith('|||'):
        text = text[:-3]
    if text.startswith('|||'):
        text = text[3:]
        
    return text.strip()

# %%
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql.functions import concat, col
from pyspark.sql.functions import col

filename = "MBTI 500"

def testData(mbti_predictor, pipeline):

    # 註冊為 PySpark UDF
    english_cleaner_udf = udf(preprocess_english_posts, StringType())

    test_data_pd = pd.read_csv(f"{filename}.csv")

    # 確保只處理包含文本和MBTI_Type的欄位
    temp_pd = test_data_pd.copy()
    temp_pd['post'] = temp_pd['Response']
    temp_pd['user_id'] = temp_pd['MBTI_Type']

    # 僅保留後續需要的欄位
    input_data_for_spark = temp_pd[['MBTI_Type', 'post', 'user_id']]

    # 定義 Schema
    schema = StructType([
        StructField("MBTI_Type", StringType(), True),
        StructField("post", StringType(), True),
        StructField("user_id", StringType(), True)
    ])

    data_rows = [tuple(x) for x in input_data_for_spark.values]

    test_data_spark = spark.createDataFrame(data_rows, schema=schema)
    test_data_spark_cleaned = test_data_spark.withColumn(
        "post",
        english_cleaner_udf(col("post"))
    )

    print("--- 預處理後的 Post 欄位 ---")
    test_data_spark_cleaned.show(truncate=False)

    predictions_spark = mbti_predictor.transform(test_data_spark_cleaned)
    results_df = predictions_spark.select(
        "user_id", 
        "post",
        col("ie_labeled_pred").alias("IE"),    
        col("ns_labeled_pred").alias("NS"),   
        col("tf_labeled_pred").alias("TF"),
        col("pj_labeled_pred").alias("PJ")
    )

    # 串接四個維度成為最終的 MBTI 類型字串
    final_predictions = results_df.withColumn(
        "prediction",
        concat(col("IE"), col("NS"), col("TF"), col("PJ"))
    )

    results_pd = final_predictions.select("user_id", "post", "prediction").toPandas()
    results_pd = results_pd.rename(columns={'user_id': 'MBTI_Type'})
    results_pd['prediction'] = results_pd['prediction'].str.upper()
    results_pd['MBTI_Type'] = results_pd['MBTI_Type'].str.upper()

    output_filename = f"mbti_predictions_results_{filename}_{pipeline}.csv"
    results_pd.to_csv(output_filename, index=False)
    
    print("\n預測結果（包含輸入文本）：")
    print(results_pd)
    print(f"\n結果已儲存到檔案: {output_filename}")
    return output_filename

# %%
import pandas as pd

def analysisResults(outputfile):

    results_pd = pd.read_csv(f"{outputfile}")
    results_pd['MBTI_Type'] = results_pd['MBTI_Type'].astype(str)
    results_pd['prediction'] = results_pd['prediction'].astype(str)

    # 確保只有長度為 4 的有效 MBTI 類型才被計算
    valid_data = results_pd[
        (results_pd['MBTI_Type'].str.len() == 4) & 
        (results_pd['prediction'].str.len() == 4)
    ].copy()

    if valid_data.empty:
        print("錯誤：沒有有效的 4 字母 MBTI 類型可供計算。請檢查 'MBTI_Type' 欄位是否正確。")
    else:
        # 提取四個維度的標籤
        valid_data['O_IE'] = valid_data['MBTI_Type'].str[0]
        valid_data['P_IE'] = valid_data['prediction'].str[0]

        valid_data['O_NS'] = valid_data['MBTI_Type'].str[1]
        valid_data['P_NS'] = valid_data['prediction'].str[1]

        valid_data['O_TF'] = valid_data['MBTI_Type'].str[2]
        valid_data['P_TF'] = valid_data['prediction'].str[2]

        valid_data['O_PJ'] = valid_data['MBTI_Type'].str[3]
        valid_data['P_PJ'] = valid_data['prediction'].str[3]
        
        total_count = len(valid_data)

        # 計算總體正確率 (4個字母完全匹配)
        overall_accuracy = (valid_data['MBTI_Type'] == valid_data['prediction']).sum() / total_count * 100

        # 計算單一維度正確率
        ie_accuracy = (valid_data['O_IE'] == valid_data['P_IE']).sum() / total_count * 100
        ns_accuracy = (valid_data['O_NS'] == valid_data['P_NS']).sum() / total_count * 100
        tf_accuracy = (valid_data['O_TF'] == valid_data['P_TF']).sum() / total_count * 100
        pj_accuracy = (valid_data['O_PJ'] == valid_data['P_PJ']).sum() / total_count * 100

        print("\n=== MBTI 預測正確率統計結果 ===")
        print(f"總計有效樣本數: {total_count}")
        print("----------------------------------------")
        print("1. 總體正確率（4個字母完全匹配）：")
        print(f"   -> {overall_accuracy:.2f}%")
        print("----------------------------------------")
        print("2. 單一維度正確率：")
        print(f"   I/E (內向/外向) 正確率: {ie_accuracy:.2f}%")
        print(f"   N/S (直覺/感覺) 正確率: {ns_accuracy:.2f}%")
        print(f"   T/F (思考/情感) 正確率: {tf_accuracy:.2f}%")
        print(f"   P/J (感知/判斷) 正確率: {pj_accuracy:.2f}%")
        print("----------------------------------------")

# %%
# 載入 PySpark 模型
if 'spark' in locals() and spark.sparkContext._jsc is not None:
    
    pipelinenumber = 202107080921
    MODEL_PATH = f"pretrainedModels/final_pipeline_{pipelinenumber}"
    
    try:

        mbti_predictor = PipelineModel.load(MODEL_PATH)
        print("PySpark 模型載入成功！")

        outputfile = testData(mbti_predictor, pipelinenumber)
        analysisResults(outputfile)
        spark.stop()
        
    except Exception as e:
        print(f"模型載入或預測階段失敗: {e}")
# Out:
# PySpark 模型載入成功！
# --- 預處理後的 Post 欄位 ---
# 25/12/11 17:17:45 WARN TaskSetManager: Stage 72 contains a task of very large size (43077 KiB). The maximum recommended task size is 1000 KiB.
# +---------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |MBTI_Type|post                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |user_id|
# +---------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# |INTJ     |know intj tool use interaction people excuse antisocial truly enlighten mastermind know would count pet peeze something time matter people either whether group people mall never see best friend sit outside conversation jsut listen want interject sit formulate say wait inject argument thought find fascinate sit watch people talk people fascinate sit class watch different people find intrigue dad intj u stand look like line safeway watch people home talk people like think military job people voluntarily go job important show deference endanger live glorify way civilian think pretty ignorant general think military necessary defense mechanism political tactic feel like u specifically invest much money could put money education whatnot though personally sound budget aernative really comment one way base two politician eye year ago come name somewhat important kinda role model nowadays pick keep score individual level mean little vary accord number condition day may score high others low sweat really good cast physiotherapist like fiberglass cast break arm whatever sometimes want take picture beast put someone arm sadly people blind brilliance need tell directly wave arm frantically totally beyond oblivious get good eye contact help lot start find like attention get opposite sex notice however gay men tend little aggressive always walk away flatter like alcohol bad start generally keep go pas run money even mention fact crave cocaine drink political power mainly desire form power okay status still never study day life never learn study feel like real whatever reason college prepare recieve people like depend career introductory course help start rid bike write essay etc choose career least stimulate mind expand perspective reality without college like kiss sound ear yup roll end quite strange confession time mind wish people le judgemental self perceive flaw run situation person confess something expect judge one way another freak realize judge gasp human interpret acknowledgement sign terrible person agree bad impulse ditch safe place quickly become somewhere dump emotional trash gui free interest play role mind noise midnight still go make really cranky lol already know autistic even know asd associate intj people mind two even remotely similar card conspiracy hallmark post office long enough people whether individual people government conglomerate corporation understand biodiversity something need fund even though make money instead insurance policy fine aka negative external form cost need separate positive surplus cost much thing like seed bank visualize cost percent farm benefit cost yet need fund separately individual farmer individual farmer corporation think well someone else people free rider problem seed bank never get set stuff like government capitalism may provide innovation government set regulation prevent negative consequence unintentional externality seed bank get set half thousand differents solution perhaps general tax commerce usage fee similar california recycle fee electronics form donation pledge system regardless need get seed bank get expert truely know enough need biodiversity seed farm whether enough seed farm different location properly fund amp bsp say expert know enough due single college class involve economics say economic class involve lot history use case study green revolution|INTJ   |
# |INTJ     |rap music ehh opp yeah know valid well know fact people like socialize party even personality let alone personality type reason remain mystery likely function stack see party goer barely function function stack well fact even get two together nigh impossible lead entire personality consist shadow function though theorize widely dismiss though may help explain inherent love night life like something stop apply eliminate genuine character flaw quickly notice rationalisation vote trump basically hillary attractive candidate lacklustre corrupt beg question president racist sexist bad really care le either way judge quality popularity stop pussy something swing go bar pick random one night stand also apps like tinder casual sex unattractive time energy relationship hire prostitute kind thing appeal masturbate use pornography imagination choice want commit relationship give advice think cover option take point realize spend much time try educate win topic reason waste energy even inflammatory topic smile let go consider personal failure let emotion get best ironically think process come read book date woman really really hot like walk heater kinda hot aggressive like intj debate find amuse literally come new rule jungian theory work base anecdotal evidence somehow make right admit good objective information really hold find research back claim get back liam nesson realization couple general truth get people tend act nice normal around one three reason want something nice normal everyone face exception say lot genuinely like people pursue call text visit unprompted fall first third category quickly determine two nature conversation people like quickly point flaw call many thing awkward weird different common theme surprise retrospect personality type rare among general population never want mindless classify conversation social activity source awkwardness defect people stop develop mentally onset puberty accept almost everyone front mental maturity year old society make much sense date toy game cheat bully tease gossip entertainment choice clique fashion bother go year high school reunion guarantee conversation cluster group would change kid get fat old imagine frodo journey mordor hard long may get lose time along way many hardship go hard get even almost may want give finally reach goal find special person world become good place forget ring always bad idea business broad field know intp programmer ob create something perfect take sweet time library rather crud tool analogy make nice chisel rather wooden bowl seem intps want carve niche become expert something change fast make money way something ntjs would enough patience master something obviously motivate intp notice correct act public let emotion private people close sup adolf luck could squander father money could nobody people inherit money time million seed money nothing term business development especially new york city incredibly hard work intelligent least come business anyone say otherwise either idiot blind partisanship far hornet go luck dog fight hit afterburner get distance make head pas enemy chase since heavy fighter figure would work communication key tell make feel blah blah blah feel thingy force love accept fact see friend romantic feel definitely able maintain friendship must let know able live                                              |INTJ   |
# |INTJ     |preferably p hd low except wew lad video p mind good reason agree statement relationship become difficu maintain people involve different stag life constantly feel though feign certain emotion counteract natural appearance aloofness excite someone engagement welcome someone bring child office internally really care either thing order mesh generally e office one strategically fake make act like thing matter family use phase anymore naturally open almost difficu fake around one occasion year feel obligate feign emotion actually comfortable around people overcome social anxiety fake emotion appear le detach completely different former take time persistent effort latter patch gauze cover wind former live fake learn comfort zone socially embrace people accept effort easily sniff counterfeit sense would take plenty vitamin get sunlight eat good visit r watchpeopledie appreciate life remember achieve thus far say intj resu trauma student study nurse something find interest body language fractal something think would really cool really understand yet mentalism one fact cool mundane common knowledge matter tell u something navajo apache descend single tribe migrate canada well sorta chief blame leaker source little foolish take basic precaution sort thing park car leave door unlock key ignition fau get steal thief still one primarily responsible idiot make easy say take photo compromise situation first place little like say could avoid theft never buy car technically true far inferior buy car lock door bed similar problem job hop since graduate land company nice crappy person like cuz still company first sale fairly well prep like excel amp nots lack severely customer service hat call finally somehow lose interest job scope initial good work erode allow shift logistics due exceptional initial stage thing happen fairly good lose focus job give another chance sale ask back logistics position feel crappy sale back logistics decide shift quality fairly well lose focus plus early stage pregnancy thus move back logistics light work tardy extend come work hour two late become moody temperamental pretty much keep barely make connection colleague surprise general manager amp ceo still ok come back maternity leave find none department want back cannot kick due local law woman back work maternity leave give final chance gm hr department new position company previously hire etc hr manager dual function finance amp hr function hr manager also temporary position finance position good get plan amp whatnot regard hire process etc course follow current cuure thats gm saw potiential sure say something genius people always one bad attitude agm speak highly person unsure real despite know lick type people work bring child goal well good environment go school etc happy planning carry thing etc punctuality wise amp interpersonally bad use lose motivation clear direction hr manager due position really hr finance really much teach even though know alot amp alot thing really find pro active point perhaps find work newly set company suggest way set direction amp planning heck even open get relevant people relevant thing master planner amp set direction best suggest vodka good stuff strong flavor smooth easy mix type                                                                                                                               |INTJ   |
# |INTJ     |drink like wish could drink red wine give headache almost instantaneously apparently people really sensitive byproduct red wine esfp bite place blissful go flow state change anything brother middle right thread really help realize need change honestly assume op know try make funny post even giggle also wonder would downvote guy people get mad get joke really know suppose one minority social recluse would quite sad buddhist strong humanist lean particularly see much geographical difference two hate sleep waste time hard stop think enough brain turn jesus christ close home every weeknight conversation wife believe men attract status way believe get degree somehow ensure end guy least much education status thing false agree false disagree woman know good woman want men high status feel like unfair smv increase status standard keep get high value stay woman good grip reality social interaction smv like reality like complain motivation go college first place largely conformism parent say society say friend go seem like fun experience go along woman naturally tend go soft subject lot social component like social science often work people help people way also value flexibility cooperation personal time competition success make sense biologically one birth raise child need aggression need social skill time child really conspiracy plot lock man biology conform society look high status male choose career field social nurture side allow raise child except iq kill unstoppable oh well guess settle mid fine long one see browser history ne seem like river manifold muiple weak current whereas ni seem like river strong current look right hate brainstorm like idea want solve problem get little bubble let brain come mental representation manipulate thing solve even try answer visualize powerfull stream water dig canyon image partially suggest mental image get strong feel like take shower edit clarity thank chan basically semi meta circlejerk implode muiple time meme cuure become obscure point exist make sense within chan like reddit everyone compete internet point everyone chan equally unimportant credit go nobody shit create simply create sake exist chan use shitty rise community chan remain odd one like wild west community cuure allow mature fester today vastly fascinate back chan use nothing literally flavor chip tune remixes still sound like chip tune sure hear thing outside professional work game example castlevania series song vampire killer first level first ne game redo dozen time castlevania iii case chip different arrangement hear backward remixes music game bite late generation devolve chip tune usually like come preferable original music old chip authentic chip tune something could original chip hardware accept tune bui use ne sample authentically example norrin radd anomaly least authentic day famitracker good enough produce ne music actually play ne authentic example jake kaufman fx originally fake sound like ne track remastered famitracker mega man example professional work sound like ne still cheat little plot thicken get feel perhaps something else go would mind go assumption like sound like analyze potential make incorrect statement head sound like defense mechanism straight really intj thing kerbal                                                                                                              |INTJ   |
# |INTJ     |space program ah bad deal meing freelance max seem get still upgrade hauler connie hate fut want build manage team play career restrict chemistry contract want play online play h h season level play field fut bad world bass player run kind issue long time realize force bassist need flashy usually get way range make distinguish note pretty difficu average listener take away overall effect band effective addition ever make song rhythmic instead think play think win play example ringo starr space fill hang back get fill feel enough time inhabit center groove feel want say time right also practice would get management train program yes use mm cannon agm hellfire missile well sure prolong talk people exhaust also call big test ex enfp relationship year live together everything cafe aulait nail head enerally get irritate end clean careless mistake think enfps struggle recognize externalitities resu action end literally get drive away middle night never talk probably win hmm ask good test take without inherent bias probably go easy however still want type understand cognitive function type accord process thing oppose characteristic type hope help first paragraph true real estate pull away necessarily relevant internet train rail accommodation business ie manufacture plant something cost actual dollar steel material labor license safety equipment large staff etc real estate near high traffic area worth seek inherently mean business due nature place physical location bui problem come attract business point eye internet concept fundamentally different since internet traffic take place local fashion physical location matter need enough overhead maintain reliable connection internet appropriate speed take potential customer anywhere world little ip address measly stream data rd world cellular connection guess get access internet basically bandwidth alone carry near much overhead physical location especially want appeal location sure management cost data center network hub imagine level maintain system rail car lease big build expensive retail park amaze benefit open internet none matter believe need push towards encourage innovation give big company load money option stay ahead simply buy appeal afford leave loser winner big cozy company stay top pay fee someone somewhere make nice live fee paper think bad example connection even slow lane deliver speed pay aka case mbps service long still access full internet content slow netflix want pay premium serve bandwidth mbps okay relatively benign least good bad however strike law threaten net neutrality start nothing ever turn upside one swoop would year late doubt end see shit like take enough away choose great plan basic mo facebook wikipedia fox news cnn news power user mo basic access bbc twitter instagram yahoo aol time warner carl jr mt dew doritos taco bell llc news medium plus mo additional plan netflix hulu youtube hbo vimeo terrorist mo access full internet complete direction monetization algorithm content delivery safegate tm internet security approve list provide f e dns availability subject change include security feature include anonymous traffic screen ensure safe balance internet experience though often something cliche often try get wish anything sit back let                                                                                                    |INTJ   |
# |INTJ     |loose stop overthinking everything ruin friendship insecurity get way learn accept difference different intjs tend feel like miss people tap feel excitement situation certainly element situation u enjoy example watch movie jot narrative thematic element borrow adapt late project real time among friend make snarky mst k commentary guess really friend appreciate offer ideal place small warm simple hut mountain long remember preferably share dog yeah definitely understand coldness mean people almost unbelievable like say though opinion way change anything reality mean attack anyone tedtalks actually come university next week pretty good channel subscribe pam due email provider true ow use email address similar sound gay cake court case year ago message cake suppose something like support gay marriage rather wed cake bert ernie sesame st owner shop refuse make religious ground take court refusal discrimination law sense say copyright ground something sometimes think fi te work together create systematic art sometimes actual art sometimes something else still artistic mean intj express make te creation pregnant personal mean read fountainhead example intj whose fi te work tandem call unorthodox old school play butterfly style everyone play day year ago goalie play outlast everyone else intj live entj already extroverted perfectionist suffer ocpd tell require much perfection think idea execution requirement environment come close match requirement someone ocpd extroverted perfectionism say however feel like much meticulous detail never diagnose tell observation may suffer x true ignorant person perspective eagle eye view ignorance bliss ignorance large body voter example give power incompetent politician far bliss come inform people presentation self beat interest experience tell people everyone act differently depend situation interact get offend change fake always person true portray honestly adapt situation would actually inappropriate act different relationship situation big fan strategy especially turn base one fire emblem xcom u greatly enjoy rpgs western foreign ahough preference jrpgs big fan shooter ahough star war battlefront ii exception lean towards thing story game play heavy good graphic nice story must case point metal gear franchise open world game interest enjoy skyrim quite bite sport game fun play fifa friend hate platformers greatly classic mario game fun never get like others zelda generally nintendo game great book favourite game world end everything fantastic game pokémon take life could possibly count regret take quick run play quite bite psn steam past performance guarantee future resus year great thing work fiering really hang happen semi social introvert well link comic ational think hit core attribute word nardio edit phone thank feed troll see top get neck shave least u injectedbacon use comma correctly context talk people often speak meet meet stage life really sorry hear girlfriend sorry must screw post link another essay always ask big plan yes go sit dark room noise cancel headphone day enjoy deal human feel pain bro embarrass nurse spend entire time apologize explode like say kind language use ut ask woman one initiate always comment dependent second part understandable seem like honestly tire old fashion way think constantly forward one seem                                     |INTJ   |
# |INTJ     |often men one put chance get burn otherwise nothing come fruition reinforce one talk sleep together even though back mind time may realize blink sign never obvious u conscious effort signaler part best one polar side situation though sign start rid obvious territory sometimes start get attempt manipulation even bad imo sorry sound bitter know ingrain society fau replicate want realize hopefully right situation remedy advance one maybe guy know put plan effort tire aggravate feel like first another guy maybe try put mean much go look type already check decide instead u throw fact indecisiveness make change opinion sp extroverted function se make crazy way answer question begin see lot fi would stick sure e though hard time trust sensor self report try use memory memory event suck human general way good remember categorize data please go look fit likely type instead bring u anecdote get annoy happen time friend start try talk something serious something find interest even try answer question ask get cut one point get tire would tell shut fuck let finish say something important like see hot female something random add anything conversation sometimes would continue finish say talk would piss usually would go minuet ask finish tell forget go say maybe late etc figure important cut every single time find friend bounce idea enrich life platonic relationship one person everything also try therapy afford look free resource online gottman institute lot practical advice resource appreciation long stop socialize people outside work exception couple coworkers consider friend unless get pay way feel bitch want spend free time attend work relate function good compensate otherwise homey play please note work job require schmooze coworkers customer job require might appropriate job introvert might suck put smiley face santa bos overthink thing time especially relationship probably always something fuck go mine usually part people im find get nice mostly non fuck significant im still overthinking thing whole system become confuse still yes fuck gotta yoga relationship yoga relationship etc remember commercial shit use coke would probably wise already ever alert spazzy side hand mbti generally take account possibility parent murder front lead dedicate life vengeance define tendency personality type say take pretend advocate trip ball dance every single time make happy edit also drug bad op mkay never ever take even purpose good fun heaven forbid drug could actually useful treat problem staal first compliment gracias something post bother bite finally get need absolve gui want make seem ex boyfriend one problem specifically place boundary throughout many sect internet headspace blatantly step boundary order state piece maybe something revolutionary say intention post would make little sense everything within unbelievably fuckin cruel make wonder vaguely sociopathic ever love love yet may get future like necessary really need hear want hurt person already want darken space probably find solace right fuck dude come literally beat someone bloody keyboard come tell specifically day literally drug house need new friend turn week ago discover frighteningly much love gin tonic suggestion prevent binge drink                                                                                                                                |INTJ   |
# |INTJ     |early definitely relate quiet self destruction dare goddamn people use place designate group socialize socialize group nerve tend regret thing equal proportion avoid say pretty balance however would say take unknown risk normally good idea go happen give set circumstance sound like might like avoid would like hear joke oort cloud second think sound cool find somewhere alone like kind free time disappear dismissive wank motion like assume right remind stephen pressfield war art get way answer apparent call bathroom break maybe go short walk get fresh air oh right fish intend fish tell try get along extrovert would almost certainly end intj spend day e without recharge type may curious well stick evidence introvert intuitive two mbti factor link poor teacher evaluation relation exam resus least med student loose well infps infjs also absolute truth matter way slice say yeah always quiet one always loud one scapegoating quiet one save hide reference fact throw bus something involvement one cause incident proof people believe cause smooth talker shit like nope topic conversation meet think entj meet notice surprise number intjs among friend say diagnose adhd give guess people like throw way much unnecessary information really want cut chase many feel medicate legitimately could doctor misdiagnosed intj type heh dumb adolescent self medicate meth couple year year clean seem like cure ill cause imagine stimulant entirely effective treat derivation add adhd afraid utilize anymore aside caffeine early thirty se ten year business analyst star trek voyager whatever mind life wait one wait nothing give way satisfy get build positive relation people fight hat extremely costly questionable return say fight defend life robber obvious talk wag endless battle meaningless trivia find someone grow old look green pasture always young beautiful body seriously overvalue believe always go find someone else go put bullshit good fake know something admit learn curve nothing wrong someone learn process mistake human learn afraid climb curve nothing sad someone win learn fear make mistake game fun waste life play game positive project work motivate go ahead help get go journey life meet people get see thing believe possible worthwhile enough people come find create creation move age euripides write medea century ago still teach school today get budget sort live within mean even especially mean really afford late great debt far reassure stress free lose sleep money pay whateveritwasyouboughtbutyoureallycouldlivewithout include medical debt anybody get sick injure fau eat well exercise every day life body ready thing need good nay great day need eat junk need eat fad eat balance diet include candy beer measure exercise keep body move design move successful long distance hunter specifically sweat sweat evolutionary advantage get read word right live life regret live honestly honourably accept go pull boner intention mean asshole natural state help someone one day might need help help cost always whatever need one really big help sure even go need many give one need find odd well since join several discussion general consensus le lazy look explain joke inline please good                                                                                                                                                                        |INTJ   |
# |INTJ     |one full list would impossibly long quotable fellow primary secondary intj counselor bake add hobby go anyway huzzah already b good sex education school instead treat like god damn taboo good access contraceptive sterilization treat woman like le want get tube tie get abortion treat men like men anymore want vasectomy archaic nonsense people gonna fuck stop would help population immensely cut whole taboo whole bloody thing educate people make option available oh man isfj son read make cringe definitely sensitive possibility spend lot time express appreciation son definitely need spend quality time together sigh help though always strong desire explain think people lot intjs really warm inside due fi think might worth share question feel mom see say yes face horror realization perfect personality picture best come leave mercy boy yet meet girl spark end relationship yesterday hop spark would come grow relationship never great girl intellectual equal need challenge debate hop eventually happen leave college year go hard meet people think try online date valedictorian get good subject math english gpa correlate success outside school always translate good skill remember wtf moment ex classmate manage graduate major year get prestigious grad school take compiler class ask basic question c program instant messenger c electrical engineer degree expose c achiever interest skill succeed class effort photographic memory force always translate good engineer glass half full oz liquid defense personal style show creativity sure possible simuaneously humble ego big maybe million ur life u meet put effort always people attract vice versa think scummiest ugly person know someone would genuinely think shit fly gold purely statistically fine find urself include lmao grill ur talkin flaw u state urself find another one without flaw happy simple also gorl make u feel feely make special lmao man sub truly immature emotional development awareness criterion wonder ave age scare blow proportion without evidence happen past billion government money divert private pharma company order develop vaccine even though lot people region immune old virus birth defect probably due different conspiracy zika fear faers false flag fraud fizzle post link link picture imgur get link karma people put link text post get accuse karma farm e sport sport catch interest similar situation let tell leave best thing first however need gauge safely leave alright term expense finance make sure safety net float around case find something right away always risky leave job without another line boyfriend know like job probably fully understand put probably realize hormonal lol affect way realize come another intj talk whole thing depth care supportive anyhow wish best luck hope keep u update esfp se fi te ni reverse u would guess seek external validation base fi amomentsreprieve probably correct fe si ne ti say spade spade spade someone cannot accept fact problem job responsible care member hatever point inconsistency guess mood shut small talk move day go well structure life around regret minimization framework implement utility maximization protocol straight male identify straight male go stop watch little pony though true mean                                                                                                                                    |INTJ   |
# |INTJ     |technique information power share unless absolutely certain way backfire hard infjs usually empathic one feel like tell everything matter good friend people keep secret steal someone feel free claim actually take without total shitbag like nice think offer want think nice side isfjs take care want make happy get annoy though think update would considerate thing really come ask opinion even le justify something feel top uncle linn entp tenure physic professor enjoy talk problem aernative green energy provide baseload aernative energy unreliable always nuclear hydro aernative energy source produce baseload power sufficient quantity preconcieved notion mostly base gen ii reactor design originally flesh improvement come along time gen iii soon come gen iv use uranium efficient reduce overall waste suppose advantage gen iv reactor radioactive waste need store century vice millennium sure still long time quite bad fact go reduce energy consumption really even need talk climate change think understand even believe climate change influence wholly due activity human pretty much beyond argument hazard burn fossil fuel personal heah acute impact environment nuclear issue much manageable far safety go minimum need good independent oversight teeth actually effect true safety program sure bad understand lack quite bite history show happen profit orient company little oversight free market solve environmental issue especially option limit none definitely know mean word choice elaborate personal choice try find balance secondly understand comment crevice go root minute detail may confuse reader thank point yes date date question first test really like however resus get interest close middle category th th grade use steal stuff need cant afford convenience store really think wrong fe like really need thing time stop steal fe bad think thats really low thing smart funny strong loud one room grad school shut naturally get plenty undeniable evidence special grow norway whole life quite reserve person like talk unless something add norway people generally reserve emotionally u also live u norwegian still value community expect know everyone get alone everyone also value behave like group stand value quite interest common group activity like ski soccer party norwegian drink lot etc resus people think arrogant really think fair different interest group think le interest wish would treat anything ahhhh priceless shall share esfj psychotherapist next week would love long mistyped holy shit last week work mention go park lunch previous day go quiet time break suddenly thank invite week try include monday fine group large today awful small group one girl ruin contradictory argumentative whole time coincidentally girl call invite lunch never busy lunch everyone else time want eat outside good muiple choice test format allow extrapolate likely answer question resu always well kind standardize test often find think consciousness separate physical reality vibrate vocal chord specific frequency convey idea pull meat flap face back indicate friendliness openness etc instead see person smile think hey happy person often think consciousness control meat bag try convey fact happy weird yes probably absurd yes absolutely legitimate plan take world matter second mean thing without help get                                                       |INTJ   |
# |INTJ     |sure ego check except immature intjs painfully slow developmentally potential chart know sure whether ego legitimate would caution put every intj see might develop ability put next shiny new plan action intj life remember three dream absurd remember day however rest know care find frankly quite irrelevant fantastic follow post everyone read midyear break right take subject midyear wake everyday finish watch digest series lecture find free internet set goal everyday though schedule set minute absolutely must hit goal bedtime usual daily goal include lecture video every series currently study read least chapter book currently read finish series lecture book currently work replace new series lecture new book go fashion lot time common introvert trait iirc tell people want sympathy go girlfriend come back want advice waste time empty attention seek behavior im day late comment anyway time right end mutual term lovely consider lucky since connect deeply lot people relationship big deal many u understandable take u lot time form meaningful connection overcome loss connection make u special seriously connect depth unrivaled majority type get pretty difficu relationship month back someone exact opposite end manipulative liar incredibly selfish resu adviced someone else r intj create list quality ex good bad bad find opposite eye coward liar want someone courageous flip flapper make mind would put list want someone know want read list remind look also matter would settle le month late meet man likelihood go become husband quality characteristic put list important thing first list loyay something liken loyay knight grail almost make fling panty across room btw huge automatically show idiot since know grail legend also remind one major issue ex know much anything perfectly fine way fine im go pretend like become problem time would also never could talk topic depth well much depth thing want talk philosophy psychology myth etc thing know much anyway tldr fuck yeah cool thank watch mathematical truth trace back fundamental axiom thing thing even arbitrary example one peano axiom natural number prove nope something agree upon truth label correlate world around u dig deep enough subject find come whether decide something true false sure thing inherently true hell none u even prove exist without shadow doubt guess ask though since really understand want experience feel place like others mean would like experience understand process work anyone could get point point person feel decision spouse feel marriage mean everything term define person imagine spouse care fe like shit despite get leave would still high opinion person let say able somehow overcome serious diagnosis die could ever consider marry person marriage game game something entertainment recreation sure treat one mean serious case spouse sick really mean much reciprocal would happen sick spouse would go play game suffer point concern would even cross mind child sake make many heahy baby attractive person even talk human anymore downgrade logic le animal sure marriage two people decide kind relationship want use self interest framework basis well fun keep marriage work loose partnership know online date work people                                                                                                                                                       |INTJ   |
# ...
# |INTJ     |kinesthetic social cecil perish replace person entirely identical every way accept small button shape mole leave buttock color whiskey view sheen april morning sunlight hate purpose seek avoid entirely control thought emotion hatred misery mass drive get position implement measure improve overall condition unfortunate hatred injustice criminality drive law enforcement protect serve everyone cuivate feel love every human without exception implement fully present every human interaction love kindness meditation help lot love everyone love nobody pertain point show love compassion towards enemy whoever might naively idealistic notion consequence thing matter make ethical decision action maximize high level pleasure best complete long term goal love self realization enlightenment k enough add say end justify mean hatred valid foundation achieve goal general apathy towards others impede achieve goal statistic data alone go fundamental logic intj dodge explain say wrong function teachable skill voluntarily learn go take class formal logic something little bite philosophy formal logic mathsy congratulation level ti literally every human deeply cognitively impair perform basic b logical think may able reason much good ti function innate literally every person nevermind fact function shorthand heuristic even describe kind empirically observable neurological process classic four temperments black bile bro exactly make life mission show loss muahahhaah mention mbti political discussion type nothing intj x intj meet sub year half ago want info look history respond post ask intj x intj relationship yt slender mythos triad marble hornet everymanhybrid tribetwelve good shit term twist story interest creative stuff creepypastas recommend night mind overview politics chris ray gun vernaculis kraut amp tea blaire white kind go tos least entertain coverage politics may sound counter intuitive maybe need attempt one final discussion tell exactly make feel long want talk probably see therapist whatever problem ignore etc try calm calmly end stop harass get police involve deserve sense security least unsoiled memory respect clearly human need pluck society sound dangerous admire vintage maximalism would like could afford someone clean instead like design think much would take clean thing revert negation separate aesthethic taste realistic desire spend time clean get independant thinker refular mbti test intj hun need little ni life ni king elaborate response sure istj fiance may main dish want life need stranger friend etc remind ni good even go home every night man ni remind thing even thing choose si man forget even fiance ni inside enfp ni inside hide want come beg something something something aka like peter pan shadow always even want run away tease p go watch hook peter bannon three form peter lawyer pan also forever young parent know man get enough seriousness real life need entertainment say rest theory specific hence want get especially sake someone begin look everything personality type vapid individual discern behavior speak vapid individual nearly productive speak wall al capitalize hide message istj intj unwilling rock boat entj intj replace smarta ambitious description estj entj ambitious best cog machine world grammar intj estj slightly le useful everyday life pretty easy well school could get b                  |INTJ   |
# |INTJ     |eye close bitch half get sure cringeworthy beat topic like sjw introduce break wall bring mind e break wall common sense decency interest like write mostly comedy actually also serious stuff comedy probably talent gift lot fanfiction original work edit want actual story pm link good example wrong general idea new people get think feel logic side people inherently go always choose logical distinction logic focus people thing fi bite hard people without much comparison base thing easy see fi think function french italian part switzerland pretend sick go excuse want touch people major relationship life year use l word never use word feel rude like sir people respond well sort openness bluntness curiosity one thing anger topic open discussion ridicule able question object concept form mental oppression suck always considerate people feel bring topic lmao make coffee banana doctor never become doctor go medicine wrong reason lack people skill even see doctor become quite annoy see another colleague much well like eye talented doctor good career need well round individual able good doctor part develop emotional intelligence people skill know doctor put social mask quite well need outside deal patient staff act however want also realize way communicate part professional image research side may good fit think job purely scientific use evidence base research back diagnosis treatment part job provide care patient part able communicate relate people effectively include heah care professional think tell patient cholesterol high flatly tell fat need lose weight help patient seek want expect support provider want resource also seek empathy guidance want robot care find another doctor provide basic care also human component medicine think care part medicine leave nurse sadly mistake heahcare move toward pay perfomance model provider cannot afford poor bedside professional manner poor customer service also closely tie poor patient outcome cannot relate well staff patient help patient uimately data collect metric show patient outcome nobody put unprofessional behavior especially since physician often work heah system long bos contract employee pattern difficu work surprise hospital want renew contract time watch happen many time see certain difficu deal doc cannot seem get contract renew keep jump job likely due intelligence ability properly diagnosis treat patient many time due poor interpersonal skill indicate still young field develop self awareness emotional intelligence would helpful sustain advance career ah gotcha use tech writer requirement analyst software think ever saw first hint process engineer beyond long suffer project manager try impose ad hoc basis oof real relationship look different different thing value partner relationship say sure bet aspect common intjs like instance tendency start date late people give story though really look relationship know would want partner also due parent divorce never intend date anyone meet guy college fe instant connection fe familiar way still explain observe quiet intelligent creative kind enough make want get know good start talk happen naturally since seat table know tend talk people close proximity several month class together major group project together start hang class together summer find go go                                                                       |INTJ   |
# |INTJ     |town state time weird hour away go family reunion go visit friend minute apart despite hour home think would fun meet could meet friend crazy fun even drink could clearly see sign undoubtedly like drink sure exactly hide interest get go bathroom friend tell talk month haha get back home finally ask situation intj intp emotion label share strong suit manage agree make official start date first kiss awkward since despite never kiss anyone sure year late tell get kiss need haha yeah nutshell kind happen force much way significant obstacle emember best year time think could correct watch video day ago someone say people usually take test moment mind probably account fluctuation take different point answer ideal self make sense know occasion struggle question think well one time mean important think follow model answer ideal self give person take test know want might provide interest resus take test twice mind day day bad self get resu even though question different tri type mean preference w first w second w possibility see still strong stoic intellectual charismatically authoritative extra ambiverted get mean preference w first w second w possibility look first time ive ever source test edit tend entj entp estp esfp estj find decent sleep schedule stick time real finish least one book month drink le leftover goal last winter play one lol game day take u lightseven intj yoga weight lift detest cardio like feel strong balance edit oh run mountain random hike always think exercise like feel free top world lie never see come robot narcissistic bore haha thank xd please meet acquaintance hope great christmas well share see someone respond reoccuringly feel judge like much judgement apply give try make feel like shit share idea likely care share even need personal feel concept new approach thing open mind know personal feel continually effect may mean disconnect time say person nope try type know year intj female really like miranda understand trait like moderation take extreme could describe insufferable much like carrie enfp fun friend could date fictional carrie know want carrie self sabotage amp bsp amp bsp sorry could give advice helpful anyway boyfriend could give advice thought feel feel sync various complexity life instead feel ill ease war muiple desire good luck amp bsp amp bsp maybe give advice watch sex city via see similar different situation rd person perspective maybe help figure feel say watch sex city watch emotional diary episode spend minute collect feel put write form aka use tv show device order ask deep question feel structure way since feel like know feel conflict extremely manipulative take advantage opportunity push sensitive boundary emotional sexual many time would belittle tell alone knife would cut extremely clingy ob mental breakdown end relationship end run away another state institutionalize mental facility damage cause long story currently recover thankfully leave many scar grant emergency protection order delete social medium get away intp date honor student extremely well however infp boyfriend like ex take advantage slowly groom                                                                                                                                                                                                                                                                |INTJ   |
# +---------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+
# only showing top 20 rows
# 25/12/11 17:17:46 WARN StringIndexerModel: Input column ie does not exist during transformation. Skip StringIndexerModel for this column.
# 25/12/11 17:17:46 WARN StringIndexerModel: Input column ns does not exist during transformation. Skip StringIndexerModel for this column.
# 25/12/11 17:17:46 WARN StringIndexerModel: Input column tf does not exist during transformation. Skip StringIndexerModel for this column.
# 25/12/11 17:17:46 WARN StringIndexerModel: Input column pj does not exist during transformation. Skip StringIndexerModel for this column.
# 25/12/11 17:17:47 WARN DAGScheduler: Broadcasting large task binary with size 5.8 MiB
# 25/12/11 17:17:47 WARN TaskSetManager: Stage 73 contains a task of very large size (43077 KiB). The maximum recommended task size is 1000 KiB.
# 25/12/11 17:17:49 WARN BLAS: Failed to load implementation from: com.github.fommil.netlib.NativeSystemBLAS
# 25/12/11 17:17:49 WARN BLAS: Failed to load implementation from: com.github.fommil.netlib.NativeRefBLAS
# 預測結果（包含輸入文本）：
#        MBTI_Type                                               post prediction
# 0           INTJ  know intj tool use interaction people excuse a...       INTJ
# 1           INTJ  rap music ehh opp yeah know valid well know fa...       INTJ
# 2           INTJ  preferably p hd low except wew lad video p min...       ESTP
# 3           INTJ  drink like wish could drink red wine give head...       INTP
# 4           INTJ  space program ah bad deal meing freelance max ...       INTP
# ...          ...                                                ...        ...
# 106062      INFP  stay frustrate world life want take long nap w...       INFJ
# 106063      INFP  fizzle around time mention sure mistake thing ...       INTP
# 106064      INFP  schedule modify hey w intp strong wing underst...       INFP
# 106065      INFP  enfj since january busy schedule able spend li...       INFP
# 106066      INFP  feel like men good problem tell parent want te...       INFJ
#
# [106067 rows x 3 columns]
#
# 結果已儲存到檔案: mbti_predictions_results_MBTI 500_202107080921.csv
#
# === MBTI 預測正確率統計結果 ===
# 總計有效樣本數: 106067
# ----------------------------------------
# 1. 總體正確率（4個字母完全匹配）：
#    -> 33.10%
# ----------------------------------------
# 2. 單一維度正確率：
#    I/E (內向/外向) 正確率: 74.22%
#    N/S (直覺/感覺) 正確率: 87.00%
#    T/F (思考/情感) 正確率: 82.40%
#    P/J (感知/判斷) 正確率: 61.21%
# ----------------------------------------
